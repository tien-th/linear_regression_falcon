# %%
# !gdown 1TpJ8GKBfxDaZ2IyoaXtTR_0shRM2F80r
# Out:
# zsh:1: /home/anaconda3/envs/BBDM/bin/gdown: bad interpreter: /root/anaconda3/envs/BBDM/bin/python: no such file or directory
# Downloading...
# From: https://drive.google.com/uc?id=1TpJ8GKBfxDaZ2IyoaXtTR_0shRM2F80r
# To: /home/huutien/falcon/data.csv
# 100%|██████████████████████████████████████| 23.7k/23.7k [00:00<00:00, 21.6MB/s]

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Momentum_3m  Momentum_1m  Volatility_3m  Volatility_1m  Sector_Return_3m  \
# 0     1.331587     1.453401       1.783313       2.095198          1.128179
# 1     0.715279     0.709627       1.798868       1.782026         -0.862216
# 2    -1.545400    -1.499311      -2.000415      -1.944532         -0.580127
# 3    -0.008384     0.057854      -0.383659      -0.106969          0.431258
# 4     0.621336     0.391826      -0.166505      -0.186213         -1.324276
#
#    Interest_Rate  Consumer_Confidence  Inflation_Rate  GDP_Growth  \
# 0       1.027840            -0.424211        0.514070   -1.325366
# 1      -0.802890            -0.050850       -0.234667    0.018548
# 2      -0.428303            -1.123754       -1.085579    0.754555
# 3      -0.755416            -1.857358        0.951746   -1.024803
# 4       0.220497            -0.216525       -0.230392    0.569934
#
#    Unemployment_Rate  Market_Volatility_Index  PE_Ratio  Exchange_Rate  \
# ...

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_df, test_df = train_test_split(df, train_size=30, test_size=50, random_state=42)

# Separate features and target
# code here
# Fit OLS Linear Regression
# code here

# Fit Ridge Regression (using default alpha=1.0 here for demonstration)
# code here

# ridge_model = Ridge(alpha=1.0)
# code here

# Evaluate performance


# Display results

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_df, test_df = train_test_split(df, train_size=30, test_size=50, random_state=42)
X_train = train_df.drop(columns="Target")
y_train = train_df["Target"]
X_test = test_df.drop(columns="Target")
y_test = test_df["Target"]

# Fit OLS Linear Regression
ols_model = LinearRegression()
ols_model.fit(X_train, y_train)

# Fit Ridge Regression (using default alpha=1.0 here for demonstration)
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)

# Evaluate performance
ols_train_mse = mean_squared_error(y_train, ols_model.predict(X_train))
ols_test_mse = mean_squared_error(y_test, ols_model.predict(X_test))
ridge_train_mse = mean_squared_error(y_train, ridge_model.predict(X_train))
ridge_test_mse = mean_squared_error(y_test, ridge_model.predict(X_test))

print(f"OLS Train MSE: {ols_train_mse:.3f}")
print(f"OLS Test MSE:  {ols_test_mse:.3f}")
print(f"Ridge Train MSE: {ridge_train_mse:.3f}")
print(f"Ridge Test MSE:  {ridge_test_mse:.3f}")
# Out:
# OLS Train MSE: 2.733
# OLS Test MSE:  7.822
# Ridge Train MSE: 3.365
# Ridge Test MSE:  5.890
